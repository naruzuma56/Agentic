# %% [markdown]
# # Structured Output
# Models can be requeseted to provide their response in a format matching a given schema. This is useful for ensuring the output can be easily parsed and used in subsequent processing. LangChian supports multiple schema types and methods for enforcing structure output.

# %% [markdown]
# ## Pydantic
# Pydantic models provides the risches feature set with field validation, descriptions and nested structures
